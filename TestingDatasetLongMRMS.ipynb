# %%
import os
os.chdir('/content/drive/MyDrive/MANU_project/MANU_Spatio-temporal/Najnovo')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/MANU_project/MANU_Spatio-temporal/Najnovo

# %%
import os
os.chdir('/content/drive/MyDrive/MANU_project/MANU_Spatio-temporal/Najnovo')

# %%
from DatasetLongMRMS import LongMRMSDataset

ds = LongMRMSDataset('/content/drive/MyDrive/MANU_project/long-MR-MS_patient01-05')
print(len(ds))
sample = ds[0]

print(sample['patient'])
print(sample['studies'])
print(sample['images'].shape)
print(sample['masks'].shape)
# Out:
# 5
# patient1
# ['study1', 'study2']
# torch.Size([2, 3, 325, 334, 53])
# torch.Size([2, 1, 325, 334, 53])
